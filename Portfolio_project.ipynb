# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
#matplotlib.rcparams['figure.figsize']=(12,8)


# Read File

df = pd.read_csv(r'C:\Users\Ayyaz\Downloads\Python Pandas\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# ## Look for Any Null data

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.dropna(subset=['writer','budget','rating','released','score','votes','gross','company','runtime'],inplace=True)

# %%
df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df.dropna(axis=1, how="any")
for col in df.columns:
    pct=np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %% [markdown]
# ## Change Data Type of Column

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget']=df['budget'].astype('int64')

df['gross']=df['gross'].astype('int64')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df.sort_values(by=['gross'],inplace=False,ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %% [markdown]
# ## Drop Duplicates

# %%
df.drop_duplicates().sum()
# Out:
# name        The ShiningThe Blue LagoonStar Wars: Episode V...
# rating      RRPGPGRRRRPGRPGPGPGRRPGPGRRRPGPGRRPGRRRRRPGPGR...
# genre       DramaAdventureActionComedyComedyHorrorActionBi...
# year                                                 10851006
# released    June 13, 1980 (United States)July 2, 1980 (Uni...
# score                                                 34653.5
# votes                                             623773486.0
# director    Stanley KubrickRandal KleiserIrvin KershnerJim...
# writer      Stephen KingHenry De Vere StacpooleLeigh Brack...
# star        Jack NicholsonBrooke ShieldsMark HamillRobert ...
# country     United KingdomUnited StatesUnited StatesUnited...
# budget                                           195205713119
# gross                                            559607950720
# company     Warner Bros.Columbia PicturesLucasfilmParamoun...
# runtime                                              586296.0
# dtype: object

# %%
df.drop_duplicates(subset=['writer','budget','rating','released','score','votes','gross','company','runtime'],inplace=True)

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Budget Vs Earning

# %%
plt.scatter(x=df['budget'],y=df['gross'])

plt.title("Budget vs Gross Earning")
plt.xlabel("Gross Earning")
plt.ylabel("budget of film")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Using Seaborn

# %%
sns.regplot(x="budget",y="gross",data=df,line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %% [markdown]
# ## Correlation

# %%
df.corr(method="pearson") ## "pearson", "kendoll", "Spearman"
# Out:
# C:\Users\Ayyaz\AppData\Local\Temp\ipykernel_4616\3737458876.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method="pearson") ## "pearson", "kendoll", "Spearman"
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
correlation_matrix=df.corr(method="pearson")

sns.heatmap(df.corr(method="pearson"),annot=True)
plt.title("Correlation Matrix")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")

plt.show()
# Out:
# C:\Users\Ayyaz\AppData\Local\Temp\ipykernel_4616\2000769170.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=df.corr(method="pearson")
# C:\Users\Ayyaz\AppData\Local\Temp\ipykernel_4616\2000769170.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method="pearson"),annot=True)

# %%
## changing the country object type into category
#for col_name in df.columns:
    #if(df[col_name].dtype == 'object'):
       # df[col_name]= df[col_name].astype('category')
        #df[col_name] = df[col_name].cat.codes
    
df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000  0.169808  0.028413  0.965461  0.966086 -0.020083
# rating    0.169808  1.000000 -0.116507  0.179456  0.171063  0.036114
# genre     0.028413 -0.116507  1.000000  0.031765  0.031251 -0.027402
# year      0.965461  0.179456  0.031765  1.000000  0.996490 -0.014594
# released  0.966086  0.171063  0.031251  0.996490  1.000000 -0.019486
# score    -0.020083  0.036114 -0.027402 -0.014594 -0.019486  1.000000
# votes     0.297305  0.097619 -0.009983  0.323916  0.313254 -0.041981
# director  0.725411  0.096014  0.036671  0.747785  0.750825 -0.006583
# writer    0.791872  0.128909  0.033975  0.812386  0.809858 -0.021538
# star      0.695124  0.115694  0.045497  0.719373  0.720076  0.015108
# country   0.098110 -0.004547 -0.003314  0.095073  0.096807  0.016567
# budget    0.288955  0.203698  0.020893  0.319135  0.309616 -0.005493
# gross     0.967925  0.172703  0.032033  0.996371  0.998490 -0.015744
# ...

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name     name        1.000000
#          rating      0.169808
#          genre       0.028413
#          year        0.965461
#          released    0.966086
#                        ...
# runtime  country     0.040813
#          budget      0.134894
#          gross       0.047728
#          company    -0.010695
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# rating   genre     -0.116507
# genre    rating    -0.116507
# budget   company   -0.053573
# company  budget    -0.053573
# score    votes     -0.041981
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# company  name       0.535369
# name     company    0.535369
# company  year       0.537731
# year     company    0.537731
# gross    company    0.545924
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 65, dtype: float64

# %%
for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes

# %%
df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1     3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2     3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3      204       4      4  1980      1127    7.7   221000.0       889    1413
# 4      732       6      4  1980      1170    7.3   108000.0       719     351
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7648   415       6      0  2020       904    6.6   140000.0        16    2390
# 7649  3556       4      0  2020       713    6.5   102000.0       852    2309
# 7650  1153       4      1  2020       904    5.6    53000.0      1809    2827
# 7651  3978       4      1  2020       758    6.8    42000.0       294    2091
# 7652  4090       3      0  2020       370    6.8     3700.0       746    1184
#
# ...

# %%
sns.stripplot(x="rating", y="gross", data=df)
# Out:
# <Axes: xlabel='rating', ylabel='gross'>
